# %% [markdown]
# # Dealing with data
#
# One of the most important parts about deep learning is data. Data is pure raw information, human and machine representation of the observation of the world. Everything can be represented in data, including our literature, arts and science. In this lab, we are going to deal with data, apply some techniques to make our data ready to be applied in a machine learning model, and after that, separate our dataset in training, validation and test datasets and feed that data to a deep learning model.

# %% [markdown]
# ## Acquiring data
#
# Before you can even prepare your dataset, you need to acquire one. Unless you already work in a place where you already have that data ready for you, you need to collect it yourself. There are a lot of places where you can acquire data, for example:
#
# - [Datasets subreddit](https://www.reddit.com/r/datasets/), a community where you can share, request and discuss about datasets;
#
# - [Kaggle](https://www.kaggle.com/), where you can search for a lot of different datasets, jupyter notebooks applying that data, and even engage in competitions;
#
# - [Awesome datasets in Github](https://github.com/awesomedata/awesome-public-datasets), a curated list of datasets of a lot of different subjects, hosted in Github.
#
# Sometimes, your data will not be easily available, and you will have to get your hands dirty to collect it. While it is beyond the scope of this lab, it is worth to mention that common data collection techniques involve the usage of sensors and [web-scraping](https://en.wikipedia.org/wiki/Web_scraping).

# %% [markdown]
# ## Preprocessing the data
#
# Let's say we downloaded the records of a HR department of a company specialized in engineering. This dataset in particular, is about the hires for a software engineering position.

# %%
# First, let's import our packages as usual.
import string
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
# Then, let's load our dataset.
import os.path
path = "./Datasets/hires.csv"
if os.path.isfile(path) :
    dataset = pd.read_csv(path)
else:
    dataset = pd.read_csv("Data/" + path)

# Let's take a look at the columns we have in this dataset.
print("Dataset Columns: {}\n".format(dataset.columns.values))
# Out:
# Dataset Columns: ['id' 'years_of_experience' 'interview_score' 'name' 'hired']

# %% [markdown]
# As you can see, we have the following features:
#
# - name: the candidate name;
# - interview_score: a subjective grade that was given to the performance of the candidate in the hiring interview;
# - years_of_experience: how many years this particular candidate has in the software engineering industry
#
# And a class:
#
# - hired: which means if the candidate ended up being hired or not;
#
#
# Now, let's take a closer look at our dataset:

# %%
# To see some of the data inside our dataset, simply use the dataset variable.
dataset
# Out:
#        id  years_of_experience  interview_score                  name  hired
# 0       1                   18             0.54        Stacia Ketchen   True
# 1       2                    6             0.29        Maryann Rumney  False
# 2       3                    6              NaN       Tristam Oliveti  False
# 3       4                    2             0.51     Andrea Gianinotti  False
# 4       5                    2             0.74         Karena Sheran   True
# ..    ...                  ...              ...                   ...    ...
# 995   996                    6             0.78        Leese Ciccoloi   True
# 996   997                    5             0.67     Inger Ivashechkin   True
# 997   998                    5             0.46  Jessalyn Bedingfield  False
# 998   999                    5             0.89        Deerdre Squibe   True
# 999  1000                    3              NaN       Demetri Coxhell  False
#
# [1000 rows x 5 columns]

# %% [markdown]
# There are some incomplete data inside our dataset. Incomplete data is, most of the times, bad data. So, we need to remove them.

# %%
import math
# Remove empty rows from dataset
for index, data in dataset.iterrows():
    if(math.isnan(data.interview_score) or math.isnan(data.years_of_experience)):
        dataset.drop(index = index, inplace = True)

# Show the updated dataset        
dataset
# Out:
#       id  years_of_experience  interview_score                  name  hired
# 0      1                   18             0.54        Stacia Ketchen   True
# 1      2                    6             0.29        Maryann Rumney  False
# 3      4                    2             0.51     Andrea Gianinotti  False
# 4      5                    2             0.74         Karena Sheran   True
# 6      7                    9             0.40    Rafaellle Goodbody  False
# ..   ...                  ...              ...                   ...    ...
# 994  995                    6             0.67     Alexine Bannister   True
# 995  996                    6             0.78        Leese Ciccoloi   True
# 996  997                    5             0.67     Inger Ivashechkin   True
# 997  998                    5             0.46  Jessalyn Bedingfield  False
# 998  999                    5             0.89        Deerdre Squibe   True
#
# [905 rows x 5 columns]

# %% [markdown]
# We also need to decide what features are important for the problem we are trying to solve. Deciding what features are important, is a key part of machine learning. Remember, bad data equals to bad results, and wrong features are bad data.
#
# In this case, the interview score and the years of experience of the candidate are important features, but the name of the candidate is completely irrelevant for our model, so we can just take it out from our dataset:

# %%
# Delete the column name
del dataset['name']
# Show our updated dataset
dataset
# Out:
#       id  years_of_experience  interview_score  hired
# 0      1                   18             0.54   True
# 1      2                    6             0.29  False
# 3      4                    2             0.51  False
# 4      5                    2             0.74   True
# 6      7                    9             0.40  False
# ..   ...                  ...              ...    ...
# 994  995                    6             0.67   True
# 995  996                    6             0.78   True
# 996  997                    5             0.67   True
# 997  998                    5             0.46  False
# 998  999                    5             0.89   True
#
# [905 rows x 4 columns]

# %% [markdown]
# Another thing that you should have in mind, is that "True" and "False", doesn't mean anything to a machine. We need to convert that into something that a computer will understand:

# %%
# Convert true to 1, and false to 0
dataset.hired = dataset.hired.astype(int)
dataset
# Out:
#       id  years_of_experience  interview_score  hired
# 0      1                   18             0.54      1
# 1      2                    6             0.29      0
# 3      4                    2             0.51      0
# 4      5                    2             0.74      1
# 6      7                    9             0.40      0
# ..   ...                  ...              ...    ...
# 994  995                    6             0.67      1
# 995  996                    6             0.78      1
# 996  997                    5             0.67      1
# 997  998                    5             0.46      0
# 998  999                    5             0.89      1
#
# [905 rows x 4 columns]

# %%
# Let's plot the dataset, so we can see who got hired and those who didn't.
dataset.plot(kind='scatter', x="interview_score", y="years_of_experience", c="hired", colormap='jet')

# %% [markdown]
# Now, let's separate our dataset into test and training datasets:

# %%
X = dataset[["years_of_experience","interview_score"]].astype(float)
Y = dataset[["hired"]]
Y = np.ravel(Y)

# Change the classes to numerical values
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
Y = np_utils.to_categorical(encoded_Y)

# Separate the dataset into test and training datasets
X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.25,)

# %% [markdown]
# Now let's build a simple classification neural network and train it:

# %%
def build_model(): 
  # Input layer
  inputs = Input([2, ], name='data')
  # Hidden layers
  model = Dense(128, activation='relu')(inputs)
  # Output layer
  outputs = Dense(2, activation='softmax', name='fc3')(model)

  # Define the model
  model = Model(inputs=[inputs], outputs=outputs)

  model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model

net = build_model()
print(net.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# data (InputLayer)            (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               384
# _________________________________________________________________
# fc3 (Dense)                  (None, 2)                 258
# =================================================================
# Total params: 642
# Trainable params: 642
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
net.fit(X_train,
        Y_train,
        validation_data=(X_test, Y_test),
        epochs=200,
        batch_size=8)
# Out:
# Train on 678 samples, validate on 227 samples
# Epoch 1/200
# 678/678 [==============================] - 0s 604us/step - loss: 0.6389 - accuracy: 0.6667 - val_loss: 0.5905 - val_accuracy: 0.7137
# Epoch 2/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.5673 - accuracy: 0.7389 - val_loss: 0.5326 - val_accuracy: 0.8238
# Epoch 3/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.4949 - accuracy: 0.8201 - val_loss: 0.4528 - val_accuracy: 0.8899
# Epoch 4/200
# 678/678 [==============================] - 0s 243us/step - loss: 0.4304 - accuracy: 0.8628 - val_loss: 0.3897 - val_accuracy: 0.9031
# Epoch 5/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.3624 - accuracy: 0.9174 - val_loss: 0.3290 - val_accuracy: 0.9559
# Epoch 6/200
# 678/678 [==============================] - 0s 241us/step - loss: 0.3107 - accuracy: 0.9381 - val_loss: 0.2826 - val_accuracy: 0.9604
# Epoch 7/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.2654 - accuracy: 0.9528 - val_loss: 0.2577 - val_accuracy: 0.9515
# Epoch 8/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.2335 - accuracy: 0.9631 - val_loss: 0.2188 - val_accuracy: 0.9736
# Epoch 9/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.2078 - accuracy: 0.9646 - val_loss: 0.2000 - val_accuracy: 0.9736
# Epoch 10/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.1893 - accuracy: 0.9602 - val_loss: 0.1828 - val_accuracy: 0.9604
# Epoch 11/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.1714 - accuracy: 0.9735 - val_loss: 0.1656 - val_accuracy: 0.9868
# Epoch 12/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.1573 - accuracy: 0.9794 - val_loss: 0.1612 - val_accuracy: 0.9559
# Epoch 13/200
# 678/678 [==============================] - 0s 222us/step - loss: 0.1490 - accuracy: 0.9720 - val_loss: 0.1679 - val_accuracy: 0.9383
# Epoch 14/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.1453 - accuracy: 0.9720 - val_loss: 0.1362 - val_accuracy: 0.9956
# Epoch 15/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.1389 - accuracy: 0.9720 - val_loss: 0.1415 - val_accuracy: 0.9648
# Epoch 16/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.1282 - accuracy: 0.9676 - val_loss: 0.1330 - val_accuracy: 0.9559
# Epoch 17/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.1177 - accuracy: 0.9794 - val_loss: 0.1348 - val_accuracy: 0.9604
# Epoch 18/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.1129 - accuracy: 0.9867 - val_loss: 0.1166 - val_accuracy: 0.9824
# Epoch 19/200
# 678/678 [==============================] - 0s 214us/step - loss: 0.1069 - accuracy: 0.9838 - val_loss: 0.1085 - val_accuracy: 0.9912
# Epoch 20/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.1017 - accuracy: 0.9764 - val_loss: 0.1295 - val_accuracy: 0.9427
# Epoch 21/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.1010 - accuracy: 0.9808 - val_loss: 0.1009 - val_accuracy: 0.9956
# Epoch 22/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.1008 - accuracy: 0.9779 - val_loss: 0.0983 - val_accuracy: 0.9868
# Epoch 23/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0933 - accuracy: 0.9779 - val_loss: 0.0946 - val_accuracy: 0.9912
# Epoch 24/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0942 - accuracy: 0.9838 - val_loss: 0.0969 - val_accuracy: 0.9868
# Epoch 25/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0888 - accuracy: 0.9823 - val_loss: 0.0909 - val_accuracy: 0.9868
# Epoch 26/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0901 - accuracy: 0.9764 - val_loss: 0.0974 - val_accuracy: 0.9736
# Epoch 27/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0861 - accuracy: 0.9794 - val_loss: 0.0898 - val_accuracy: 0.9912
# Epoch 28/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0880 - accuracy: 0.9720 - val_loss: 0.0838 - val_accuracy: 0.9868
# Epoch 29/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0816 - accuracy: 0.9867 - val_loss: 0.0844 - val_accuracy: 0.9824
# Epoch 30/200
# 678/678 [==============================] - 0s 237us/step - loss: 0.0812 - accuracy: 0.9720 - val_loss: 0.0848 - val_accuracy: 0.9824
# Epoch 31/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0829 - accuracy: 0.9661 - val_loss: 0.0807 - val_accuracy: 0.9868
# Epoch 32/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0729 - accuracy: 0.9867 - val_loss: 0.0837 - val_accuracy: 0.9824
# Epoch 33/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0746 - accuracy: 0.9823 - val_loss: 0.1375 - val_accuracy: 0.9295
# Epoch 34/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0715 - accuracy: 0.9823 - val_loss: 0.0752 - val_accuracy: 0.9868
# Epoch 35/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0706 - accuracy: 0.9794 - val_loss: 0.0726 - val_accuracy: 0.9912
# Epoch 36/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0654 - accuracy: 0.9882 - val_loss: 0.0708 - val_accuracy: 0.9956
# Epoch 37/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0699 - accuracy: 0.9808 - val_loss: 0.0835 - val_accuracy: 0.9648
# Epoch 38/200
# 678/678 [==============================] - 0s 240us/step - loss: 0.0616 - accuracy: 0.9867 - val_loss: 0.0935 - val_accuracy: 0.9515
# Epoch 39/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0648 - accuracy: 0.9823 - val_loss: 0.0682 - val_accuracy: 0.9956
# Epoch 40/200
# 678/678 [==============================] - 0s 222us/step - loss: 0.0630 - accuracy: 0.9882 - val_loss: 0.0662 - val_accuracy: 0.9956
# Epoch 41/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0723 - accuracy: 0.9794 - val_loss: 0.0719 - val_accuracy: 0.9824
# Epoch 42/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0674 - accuracy: 0.9794 - val_loss: 0.0824 - val_accuracy: 0.9604
# Epoch 43/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0668 - accuracy: 0.9764 - val_loss: 0.0657 - val_accuracy: 0.9912
# Epoch 44/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.0586 - accuracy: 0.9867 - val_loss: 0.0661 - val_accuracy: 0.9824
# Epoch 45/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.0606 - accuracy: 0.9882 - val_loss: 0.0616 - val_accuracy: 0.9956
# Epoch 46/200
# 678/678 [==============================] - 0s 216us/step - loss: 0.0590 - accuracy: 0.9912 - val_loss: 0.0699 - val_accuracy: 0.9824
# Epoch 47/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0590 - accuracy: 0.9838 - val_loss: 0.0764 - val_accuracy: 0.9648
# Epoch 48/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0597 - accuracy: 0.9853 - val_loss: 0.0640 - val_accuracy: 0.9912
# Epoch 49/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0615 - accuracy: 0.9882 - val_loss: 0.0984 - val_accuracy: 0.9515
# Epoch 50/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0495 - accuracy: 0.9941 - val_loss: 0.0595 - val_accuracy: 0.9956
# Epoch 51/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0570 - accuracy: 0.9838 - val_loss: 0.0577 - val_accuracy: 0.9956
# Epoch 52/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0644 - accuracy: 0.9794 - val_loss: 0.1027 - val_accuracy: 0.9471
# Epoch 53/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0615 - accuracy: 0.9823 - val_loss: 0.0578 - val_accuracy: 0.9912
# Epoch 54/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0521 - accuracy: 0.9867 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 55/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0575 - accuracy: 0.9867 - val_loss: 0.0634 - val_accuracy: 0.9824
# Epoch 56/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0504 - accuracy: 0.9897 - val_loss: 0.0560 - val_accuracy: 0.9868
# Epoch 57/200
# 678/678 [==============================] - 0s 242us/step - loss: 0.0516 - accuracy: 0.9897 - val_loss: 0.0578 - val_accuracy: 0.9824
# Epoch 58/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0517 - accuracy: 0.9912 - val_loss: 0.0693 - val_accuracy: 0.9692
# Epoch 59/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0513 - accuracy: 0.9867 - val_loss: 0.0548 - val_accuracy: 0.9868
# Epoch 60/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0548 - accuracy: 0.9838 - val_loss: 0.0559 - val_accuracy: 0.9824
# Epoch 61/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0526 - accuracy: 0.9853 - val_loss: 0.0527 - val_accuracy: 0.9868
# Epoch 62/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0546 - accuracy: 0.9794 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 63/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0514 - accuracy: 0.9853 - val_loss: 0.0565 - val_accuracy: 0.9912
# Epoch 64/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0478 - accuracy: 0.9867 - val_loss: 0.0624 - val_accuracy: 0.9824
# Epoch 65/200
# 678/678 [==============================] - 0s 236us/step - loss: 0.0564 - accuracy: 0.9808 - val_loss: 0.0509 - val_accuracy: 0.9868
# Epoch 66/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0593 - accuracy: 0.9764 - val_loss: 0.0490 - val_accuracy: 0.9956
# Epoch 67/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0433 - accuracy: 0.9926 - val_loss: 0.0591 - val_accuracy: 0.9824
# Epoch 68/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0478 - accuracy: 0.9912 - val_loss: 0.0507 - val_accuracy: 0.9956
# Epoch 69/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0479 - accuracy: 0.9838 - val_loss: 0.0480 - val_accuracy: 0.9912
# Epoch 70/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0456 - accuracy: 0.9882 - val_loss: 0.0472 - val_accuracy: 0.9956
# Epoch 71/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0449 - accuracy: 0.9912 - val_loss: 0.0488 - val_accuracy: 0.9868
# Epoch 72/200
# 678/678 [==============================] - 0s 236us/step - loss: 0.0496 - accuracy: 0.9838 - val_loss: 0.0542 - val_accuracy: 0.9824
# Epoch 73/200
# 678/678 [==============================] - 0s 239us/step - loss: 0.0438 - accuracy: 0.9897 - val_loss: 0.0763 - val_accuracy: 0.9559
# Epoch 74/200
# 678/678 [==============================] - 0s 239us/step - loss: 0.0647 - accuracy: 0.9749 - val_loss: 0.0644 - val_accuracy: 0.9692
# Epoch 75/200
# 678/678 [==============================] - 0s 260us/step - loss: 0.0625 - accuracy: 0.9749 - val_loss: 0.0573 - val_accuracy: 0.9824
# Epoch 76/200
# 678/678 [==============================] - 0s 338us/step - loss: 0.0580 - accuracy: 0.9808 - val_loss: 0.1001 - val_accuracy: 0.9515
# Epoch 77/200
# 678/678 [==============================] - 0s 241us/step - loss: 0.0483 - accuracy: 0.9838 - val_loss: 0.0493 - val_accuracy: 0.9824
# Epoch 78/200
# 678/678 [==============================] - 0s 242us/step - loss: 0.0448 - accuracy: 0.9853 - val_loss: 0.0471 - val_accuracy: 0.9868
# Epoch 79/200
# 678/678 [==============================] - 0s 238us/step - loss: 0.0419 - accuracy: 0.9897 - val_loss: 0.0486 - val_accuracy: 0.9824
# Epoch 80/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0493 - accuracy: 0.9867 - val_loss: 0.0461 - val_accuracy: 0.9868
# Epoch 81/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0414 - accuracy: 0.9926 - val_loss: 0.0438 - val_accuracy: 0.9956
# Epoch 82/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0482 - accuracy: 0.9853 - val_loss: 0.0451 - val_accuracy: 0.9956
# Epoch 83/200
# 678/678 [==============================] - 0s 236us/step - loss: 0.0478 - accuracy: 0.9867 - val_loss: 0.0633 - val_accuracy: 0.9692
# Epoch 84/200
# 678/678 [==============================] - 0s 242us/step - loss: 0.0469 - accuracy: 0.9882 - val_loss: 0.0431 - val_accuracy: 0.9912
# Epoch 85/200
# 678/678 [==============================] - 0s 249us/step - loss: 0.0395 - accuracy: 0.9912 - val_loss: 0.0458 - val_accuracy: 0.9912
# Epoch 86/200
# 678/678 [==============================] - 0s 238us/step - loss: 0.0484 - accuracy: 0.9853 - val_loss: 0.0622 - val_accuracy: 0.9736
# Epoch 87/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0479 - accuracy: 0.9823 - val_loss: 0.0455 - val_accuracy: 0.9868
# Epoch 88/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0439 - accuracy: 0.9838 - val_loss: 0.0517 - val_accuracy: 0.9824
# Epoch 89/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0394 - accuracy: 0.9867 - val_loss: 0.0436 - val_accuracy: 0.9912
# Epoch 90/200
# 678/678 [==============================] - 0s 243us/step - loss: 0.0398 - accuracy: 0.9926 - val_loss: 0.0550 - val_accuracy: 0.9824
# Epoch 91/200
# 678/678 [==============================] - 0s 242us/step - loss: 0.0546 - accuracy: 0.9749 - val_loss: 0.0457 - val_accuracy: 0.9912
# Epoch 92/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0428 - accuracy: 0.9838 - val_loss: 0.0645 - val_accuracy: 0.9692
# Epoch 93/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0371 - accuracy: 0.9941 - val_loss: 0.0452 - val_accuracy: 0.9824
# Epoch 94/200
# 678/678 [==============================] - 0s 236us/step - loss: 0.0437 - accuracy: 0.9838 - val_loss: 0.0406 - val_accuracy: 0.9912
# Epoch 95/200
# 678/678 [==============================] - 0s 260us/step - loss: 0.0353 - accuracy: 0.9912 - val_loss: 0.0403 - val_accuracy: 0.9956
# Epoch 96/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0433 - accuracy: 0.9912 - val_loss: 0.0435 - val_accuracy: 0.9824
# Epoch 97/200
# 678/678 [==============================] - 0s 237us/step - loss: 0.0417 - accuracy: 0.9882 - val_loss: 0.0424 - val_accuracy: 0.9868
# Epoch 98/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.0592 - val_accuracy: 0.9736
# Epoch 99/200
# 678/678 [==============================] - 0s 241us/step - loss: 0.0417 - accuracy: 0.9897 - val_loss: 0.0410 - val_accuracy: 0.9956
# Epoch 100/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0392 - accuracy: 0.9867 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 101/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0497 - accuracy: 0.9779 - val_loss: 0.0415 - val_accuracy: 0.9824
# Epoch 102/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0408 - accuracy: 0.9838 - val_loss: 0.0385 - val_accuracy: 0.9912
# Epoch 103/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.0389 - accuracy: 0.9867 - val_loss: 0.0445 - val_accuracy: 0.9824
# Epoch 104/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0342 - accuracy: 0.9912 - val_loss: 0.0455 - val_accuracy: 0.9912
# Epoch 105/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0413 - accuracy: 0.9823 - val_loss: 0.0402 - val_accuracy: 0.9868
# Epoch 106/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 107/200
# 678/678 [==============================] - 0s 239us/step - loss: 0.0334 - accuracy: 0.9897 - val_loss: 0.0447 - val_accuracy: 0.9912
# Epoch 108/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0423 - accuracy: 0.9867 - val_loss: 0.0456 - val_accuracy: 0.9824
# Epoch 109/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0375 - accuracy: 0.9882 - val_loss: 0.0379 - val_accuracy: 0.9956
# Epoch 110/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0415 - accuracy: 0.9882 - val_loss: 0.0383 - val_accuracy: 0.9956
# Epoch 111/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0365 - accuracy: 0.9926 - val_loss: 0.0388 - val_accuracy: 0.9868
# Epoch 112/200
# 678/678 [==============================] - 0s 249us/step - loss: 0.0348 - accuracy: 0.9926 - val_loss: 0.0364 - val_accuracy: 0.9956
# Epoch 113/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0345 - accuracy: 0.9941 - val_loss: 0.0507 - val_accuracy: 0.9824
# Epoch 114/200
# 678/678 [==============================] - 0s 218us/step - loss: 0.0383 - accuracy: 0.9853 - val_loss: 0.0719 - val_accuracy: 0.9604
# Epoch 115/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0710 - accuracy: 0.9646 - val_loss: 0.0361 - val_accuracy: 0.9912
# Epoch 116/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0365 - accuracy: 0.9867 - val_loss: 0.0628 - val_accuracy: 0.9692
# Epoch 117/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0346 - accuracy: 0.9926 - val_loss: 0.0472 - val_accuracy: 0.9824
# Epoch 118/200
# 678/678 [==============================] - 0s 243us/step - loss: 0.0355 - accuracy: 0.9897 - val_loss: 0.0356 - val_accuracy: 0.9956
# Epoch 119/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0311 - accuracy: 0.9941 - val_loss: 0.0384 - val_accuracy: 0.9868
# Epoch 120/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0316 - accuracy: 0.9956 - val_loss: 0.0352 - val_accuracy: 0.9956
# Epoch 121/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0376 - accuracy: 0.9897 - val_loss: 0.0461 - val_accuracy: 0.9868
# Epoch 122/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0353 - accuracy: 0.9912 - val_loss: 0.0375 - val_accuracy: 0.9956
# Epoch 123/200
# 678/678 [==============================] - 0s 216us/step - loss: 0.0383 - accuracy: 0.9853 - val_loss: 0.0369 - val_accuracy: 0.9868
# Epoch 124/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0355 - accuracy: 0.9897 - val_loss: 0.0520 - val_accuracy: 0.9780
# Epoch 125/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0389 - accuracy: 0.9882 - val_loss: 0.0494 - val_accuracy: 0.9824
# Epoch 126/200
# 678/678 [==============================] - 0s 222us/step - loss: 0.0347 - accuracy: 0.9882 - val_loss: 0.0390 - val_accuracy: 0.9868
# Epoch 127/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.0376 - accuracy: 0.9897 - val_loss: 0.0569 - val_accuracy: 0.9736
# Epoch 128/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0557 - accuracy: 0.9794 - val_loss: 0.0456 - val_accuracy: 0.9824
# Epoch 129/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0433 - accuracy: 0.9853 - val_loss: 0.0347 - val_accuracy: 0.9956
# Epoch 130/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0340 - val_accuracy: 0.9956
# Epoch 131/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0325 - accuracy: 0.9867 - val_loss: 0.0333 - val_accuracy: 0.9956
# Epoch 132/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0310 - accuracy: 0.9897 - val_loss: 0.0335 - val_accuracy: 0.9912
# Epoch 133/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0315 - accuracy: 0.9897 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 134/200
# 678/678 [==============================] - 0s 235us/step - loss: 0.0388 - accuracy: 0.9941 - val_loss: 0.0655 - val_accuracy: 0.9648
# Epoch 135/200
# 678/678 [==============================] - 0s 235us/step - loss: 0.0332 - accuracy: 0.9912 - val_loss: 0.0336 - val_accuracy: 0.9868
# Epoch 136/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0316 - accuracy: 0.9926 - val_loss: 0.0412 - val_accuracy: 0.9824
# Epoch 137/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0318 - accuracy: 0.9941 - val_loss: 0.0422 - val_accuracy: 0.9824
# Epoch 138/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0359 - accuracy: 0.9867 - val_loss: 0.0841 - val_accuracy: 0.9604
# Epoch 139/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0391 - accuracy: 0.9808 - val_loss: 0.0457 - val_accuracy: 0.9824
# Epoch 140/200
# 678/678 [==============================] - 0s 243us/step - loss: 0.0281 - accuracy: 0.9897 - val_loss: 0.0806 - val_accuracy: 0.9559
# Epoch 141/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0347 - accuracy: 0.9912 - val_loss: 0.0360 - val_accuracy: 0.9868
# Epoch 142/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0341 - accuracy: 0.9897 - val_loss: 0.0371 - val_accuracy: 0.9912
# Epoch 143/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0428 - accuracy: 0.9867 - val_loss: 0.0527 - val_accuracy: 0.9780
# Epoch 144/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0352 - accuracy: 0.9912 - val_loss: 0.0314 - val_accuracy: 1.0000
# Epoch 145/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0295 - accuracy: 0.9897 - val_loss: 0.0354 - val_accuracy: 0.9912
# Epoch 146/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0358 - accuracy: 0.9823 - val_loss: 0.0401 - val_accuracy: 0.9824
# Epoch 147/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.0425 - accuracy: 0.9882 - val_loss: 0.0331 - val_accuracy: 0.9868
# Epoch 148/200
# 678/678 [==============================] - 0s 224us/step - loss: 0.0320 - accuracy: 0.9867 - val_loss: 0.0367 - val_accuracy: 0.9824
# Epoch 149/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.0462 - val_accuracy: 0.9824
# Epoch 150/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0344 - accuracy: 0.9912 - val_loss: 0.0308 - val_accuracy: 0.9956
# Epoch 151/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0301 - accuracy: 0.9912 - val_loss: 0.0312 - val_accuracy: 0.9912
# Epoch 152/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0316 - accuracy: 0.9926 - val_loss: 0.0349 - val_accuracy: 0.9912
# Epoch 153/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0333 - accuracy: 0.9897 - val_loss: 0.0307 - val_accuracy: 0.9912
# Epoch 154/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0408 - accuracy: 0.9823 - val_loss: 0.0677 - val_accuracy: 0.9648
# Epoch 155/200
# 678/678 [==============================] - 0s 217us/step - loss: 0.0489 - accuracy: 0.9779 - val_loss: 0.0320 - val_accuracy: 0.9956
# Epoch 156/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0280 - accuracy: 0.9941 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 157/200
# 678/678 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.98 - 0s 221us/step - loss: 0.0411 - accuracy: 0.9882 - val_loss: 0.0314 - val_accuracy: 0.9956
# Epoch 158/200
# 678/678 [==============================] - 0s 226us/step - loss: 0.0470 - accuracy: 0.9838 - val_loss: 0.0300 - val_accuracy: 0.9956
# Epoch 159/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0412 - accuracy: 0.9823 - val_loss: 0.0751 - val_accuracy: 0.9559
# Epoch 160/200
# 678/678 [==============================] - 0s 222us/step - loss: 0.0314 - accuracy: 0.9941 - val_loss: 0.0458 - val_accuracy: 0.9780
# Epoch 161/200
# 678/678 [==============================] - 0s 217us/step - loss: 0.0301 - accuracy: 0.9926 - val_loss: 0.0314 - val_accuracy: 0.9868
# Epoch 162/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0308 - accuracy: 0.9941 - val_loss: 0.0336 - val_accuracy: 0.9868
# Epoch 163/200
# 678/678 [==============================] - 0s 215us/step - loss: 0.0298 - accuracy: 0.9941 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 164/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0334 - accuracy: 0.9867 - val_loss: 0.0365 - val_accuracy: 0.9824
# Epoch 165/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0286 - accuracy: 0.9897 - val_loss: 0.0311 - val_accuracy: 0.9868
# Epoch 166/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0323 - accuracy: 0.9853 - val_loss: 0.0288 - val_accuracy: 0.9956
# Epoch 167/200
# 678/678 [==============================] - 0s 214us/step - loss: 0.0341 - accuracy: 0.9853 - val_loss: 0.0305 - val_accuracy: 0.9956
# Epoch 168/200
# 678/678 [==============================] - 0s 229us/step - loss: 0.0265 - accuracy: 0.9956 - val_loss: 0.0372 - val_accuracy: 0.9824
# Epoch 169/200
# 678/678 [==============================] - 0s 240us/step - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.0286 - val_accuracy: 0.9956
# Epoch 170/200
# 678/678 [==============================] - 0s 233us/step - loss: 0.0264 - accuracy: 0.9941 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 171/200
# 678/678 [==============================] - 0s 228us/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.0314 - val_accuracy: 0.9868
# Epoch 172/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0324 - accuracy: 0.9897 - val_loss: 0.0307 - val_accuracy: 0.9868
# Epoch 173/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0332 - accuracy: 0.9882 - val_loss: 0.0285 - val_accuracy: 0.9956
# Epoch 174/200
# 678/678 [==============================] - 0s 214us/step - loss: 0.0278 - accuracy: 0.9941 - val_loss: 0.0294 - val_accuracy: 0.9956
# Epoch 175/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0322 - accuracy: 0.9912 - val_loss: 0.0296 - val_accuracy: 0.9956
# Epoch 176/200
# 678/678 [==============================] - 0s 223us/step - loss: 0.0252 - accuracy: 0.9941 - val_loss: 0.0371 - val_accuracy: 0.9824
# Epoch 177/200
# 678/678 [==============================] - 0s 240us/step - loss: 0.0357 - accuracy: 0.9867 - val_loss: 0.0315 - val_accuracy: 0.9868
# Epoch 178/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0254 - accuracy: 0.9926 - val_loss: 0.0328 - val_accuracy: 0.9824
# Epoch 179/200
# 678/678 [==============================] - 0s 225us/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.0372 - val_accuracy: 0.9824
# Epoch 180/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.0304 - val_accuracy: 0.9956
# Epoch 181/200
# 678/678 [==============================] - 0s 236us/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.0396 - val_accuracy: 0.9912
# Epoch 182/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0295 - accuracy: 0.9897 - val_loss: 0.0343 - val_accuracy: 0.9824
# Epoch 183/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0251 - accuracy: 0.9941 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 184/200
# 678/678 [==============================] - 0s 234us/step - loss: 0.0295 - accuracy: 0.9912 - val_loss: 0.0315 - val_accuracy: 0.9956
# Epoch 185/200
# 678/678 [==============================] - 0s 231us/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.0309 - val_accuracy: 0.9956
# Epoch 186/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0437 - accuracy: 0.9794 - val_loss: 0.0450 - val_accuracy: 0.9824
# Epoch 187/200
# 678/678 [==============================] - 0s 232us/step - loss: 0.0361 - accuracy: 0.9808 - val_loss: 0.0296 - val_accuracy: 0.9956
# Epoch 188/200
# 678/678 [==============================] - 0s 247us/step - loss: 0.0247 - accuracy: 0.9941 - val_loss: 0.0331 - val_accuracy: 0.9824
# Epoch 189/200
# 678/678 [==============================] - 0s 246us/step - loss: 0.0246 - accuracy: 0.9941 - val_loss: 0.0377 - val_accuracy: 0.9824
# Epoch 190/200
# 678/678 [==============================] - 0s 230us/step - loss: 0.0223 - accuracy: 0.9941 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 191/200
# 678/678 [==============================] - 0s 220us/step - loss: 0.0377 - accuracy: 0.9838 - val_loss: 0.0279 - val_accuracy: 0.9868
# Epoch 192/200
# 678/678 [==============================] - 0s 209us/step - loss: 0.0248 - accuracy: 0.9897 - val_loss: 0.0572 - val_accuracy: 0.9736
# Epoch 193/200
# 678/678 [==============================] - 0s 227us/step - loss: 0.0288 - accuracy: 0.9897 - val_loss: 0.0324 - val_accuracy: 0.9824
# Epoch 194/200
# 678/678 [==============================] - 0s 207us/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.0312 - val_accuracy: 0.9956
# Epoch 195/200
# 678/678 [==============================] - 0s 217us/step - loss: 0.0264 - accuracy: 0.9897 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 196/200
# 678/678 [==============================] - 0s 217us/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 197/200
# 678/678 [==============================] - 0s 221us/step - loss: 0.0253 - accuracy: 0.9912 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 198/200
# 678/678 [==============================] - 0s 219us/step - loss: 0.0321 - accuracy: 0.9882 - val_loss: 0.0460 - val_accuracy: 0.9824
# Epoch 199/200
# 678/678 [==============================] - 0s 212us/step - loss: 0.0369 - accuracy: 0.9882 - val_loss: 0.0408 - val_accuracy: 0.9868
# Epoch 200/200
# 678/678 [==============================] - 0s 216us/step - loss: 0.0354 - accuracy: 0.9867 - val_loss: 0.0312 - val_accuracy: 0.9912

# %%
# Print model performance
test_loss, test_acc = net.evaluate(X_test,  Y_test, verbose=2)
print('\nTest accuracy:', test_acc)

# Predict if a new candidate with interview score of 0.6 and 15 years of experience will be hired
input = np.array([[15,0.6]])
prediction = net.predict(input)
for index, predict in enumerate(prediction):
  if predict[0]*100 > predict[1]*100:
    print("Candidate probably will not be hired")
  else:
    print("Candidate probably will be hired")
# Out:
# Test accuracy: 0.9911894202232361
# Candidate probably will be hired
